# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///russian_losses.db')

# %%
df_personnel = pd.read_sql('tb_personnel', engine)
df_personnel
# Out:
#     observation_date  day_of_war  personnel personnel_about   pows
# 0         2022-02-25           2       2800           about    0.0
# 1         2022-02-26           3       4300           about    0.0
# 2         2022-02-27           4       4500           about    0.0
# 3         2022-02-28           5       5300           about    0.0
# 4         2022-03-01           6       5710           about  200.0
# ..               ...         ...        ...             ...    ...
# 334       2023-01-25         336     123080           about    NaN
# 335       2023-01-26         337     123860           about    NaN
# 336       2023-01-27         338     124710           about    NaN
# 337       2023-01-28         339     125510           about    NaN
# 338       2023-01-29         340     126160           about    NaN
#
# [339 rows x 5 columns]

# %%
df_personnel.to_csv('data/processed/personnel.csv', index=False)

# %%
df_equip = pd.read_sql('tb_equipment', engine)
df_equip
# Out:
#     observation_date  day_of_war  aircraft  helicopter  tank   APC  \
# 0         2022-02-25           2        10           7    80   516
# 1         2022-02-26           3        27          26   146   706
# 2         2022-02-27           4        27          26   150   706
# 3         2022-02-28           5        29          29   150   816
# 4         2022-03-01           6        29          29   198   846
# ..               ...         ...       ...         ...   ...   ...
# 334       2023-01-25         336       290         281  3161  6307
# 335       2023-01-26         337       292         282  3175  6334
# 336       2023-01-27         338       292         283  3182  6340
# 337       2023-01-28         339       293         284  3189  6344
# 338       2023-01-29         340       293         284  3197  6366
#
#      field_artilery  mrl  military_auto  fuel_tank  drone  naval_ship  \
# 0                49    4          100.0       60.0      0           2
# ...

# %%
df_equip.to_csv('data/processed/equipment.csv', index=False)
